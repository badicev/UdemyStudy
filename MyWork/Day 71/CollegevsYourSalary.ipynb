# %% [markdown]
# ------------------------------- Data Exploration with Pandas: College Major vs. Your Salary ----------------------------------------------

# %%
import pandas as pd
salary_data = pd.read_csv('salaries_by_college_major.csv')
salary_data.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
salary_data.shape
# Out:
# (51, 6)

# %%
salary_data.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
salary_data.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
salary_data.isna().sum()
# Out:
# Undergraduate Major                  0
# Starting Median Salary               1
# Mid-Career Median Salary             1
# Mid-Career 10th Percentile Salary    1
# Mid-Career 90th Percentile Salary    1
# Group                                1
# dtype: int64

# %%
salary_data.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = salary_data.dropna()
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
clean_df['Starting Median Salary']
# Out:
# 0     46000.0
# 1     57700.0
# 2     42600.0
# 3     36800.0
# 4     41600.0
# 5     35800.0
# 6     38800.0
# 7     43000.0
# 8     63200.0
# 9     42600.0
# 10    53900.0
# 11    38100.0
# 12    61400.0
# 13    55900.0
# 14    53700.0
# 15    35000.0
# 16    35900.0
# 17    50100.0
# 18    34900.0
# 19    60900.0
# 20    38000.0
# 21    37900.0
# 22    47900.0
# 23    39100.0
# 24    41200.0
# 25    43500.0
# 26    35700.0
# 27    38800.0
# 28    39200.0
# 29    37800.0
# 30    57700.0
# 31    49100.0
# 32    36100.0
# 33    40900.0
# 34    35600.0
# 35    49200.0
# 36    40800.0
# 37    45400.0
# 38    57900.0
# 39    35900.0
# 40    54200.0
# 41    39900.0
# 42    39900.0
# 43    74300.0
# 44    50300.0
# 45    40800.0
# 46    35900.0
# 47    34100.0
# 48    36500.0
# 49    34000.0
# Name: Starting Median Salary, dtype: float64

# %%
clean_df['Starting Median Salary'].max()
# Out:
# 74300.0

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
clean_df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %% [markdown]
# What college major has the highest mid-career salary? How much do graduates with this major earn? (Mid-career is defined as having 10+ years of experience).

# %%
clean_df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
clean_df.loc[clean_df['Mid-Career Median Salary'].idxmax()]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %% [markdown]
# Which college major has the lowest starting salary and how much do graduates earn after university?

# %%
clean_df.loc[clean_df['Starting Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %% [markdown]
# Which college major has the lowest mid-career salary and how much can people expect to earn with this degree?

# %%
clean_df.loc[clean_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %% [markdown]
# **Sorting Values & Adding Columns: Majors with the Most Potential vs Lowest Risk**

# %%
clean_df['diff'] = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
# Out:
# C:\Users\basak\AppData\Local\Temp\ipykernel_28984\3459181681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['diff'] = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']

# %%
low_risk = clean_df['diff'].sort_values(ascending=True)
clean_df.loc[low_risk.index]
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 40                               Nursing                 54200.0
# 43                   Physician Assistant                 74300.0
# 41                             Nutrition                 39900.0
# 49                               Spanish                 34000.0
# 27            Health Care Administration                 38800.0
# 47                              Religion                 34100.0
# 23                              Forestry                 39100.0
# 32                       Interior Design                 36100.0
# 18                             Education                 34900.0
# 15                      Criminal Justice                 35000.0
# 26                        Graphic Design                 35700.0
# 31           Information Technology (IT)                 49100.0
# 10                     Civil Engineering                 53900.0
# ...

# %% [markdown]
# Find the top 5 degrees with the highest values in the 90th percentile.

# %%
clean_df.loc[clean_df['Mid-Career 90th Percentile Salary'].sort_values(ascending=False).index].head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17             Economics                 50100.0                   98600.0
# 22               Finance                 47900.0                   88300.0
# 8   Chemical Engineering                 63200.0                  107000.0
# 37                  Math                 45400.0                   92400.0
# 44               Physics                 50300.0                   97300.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 8                             71900.0                           194000.0
# 37                            45200.0                           183000.0
# 44                            56000.0                           178000.0
#
#        Group      diff
# 17  Business  159400.0
# 22  Business  147800.0
# ...

# %% [markdown]
# Find the degrees with the greatest spread in salaries.

# %%
clean_df.loc[clean_df["diff"].sort_values(ascending=False).index].head()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17           Economics                 50100.0                   98600.0
# 22             Finance                 47900.0                   88300.0
# 37                Math                 45400.0                   92400.0
# 36           Marketing                 40800.0                   79600.0
# 42          Philosophy                 39900.0                   81200.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 37                            45200.0                           183000.0
# 36                            42100.0                           175000.0
# 42                            35500.0                           168000.0
#
#        Group      diff
# 17  Business  159400.0
# 22  Business  147800.0
# ...

# %%
highest_spread = clean_df.sort_values('Mid-Career Median Salary', ascending=False)
highest_spread.head()
# Out:
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 8     Chemical Engineering                 63200.0                  107000.0
# 12    Computer Engineering                 61400.0                  105000.0
# 19  Electrical Engineering                 60900.0                  103000.0
# 1    Aerospace Engineering                 57700.0                  101000.0
# 17               Economics                 50100.0                   98600.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 8                             71900.0                           194000.0
# 12                            66100.0                           162000.0
# 19                            69300.0                           168000.0
# 1                             64300.0                           161000.0
# 17                            50600.0                           210000.0
#
#        Group      diff
# 8       STEM  122100.0
# ...

# %% [markdown]
# **Grouping and Pivoting Data with Pandas**

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Starting Median Salary  \
# Group
# Business                   12                      12
# HASS                       22                      22
# STEM                       16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary  diff
# Group
# Business                                 12    12
# HASS                                     22    22
# STEM                                     16    16

# %%
clean_df.groupby('Group').mean()
# Out:
# C:\Users\basak\AppData\Local\Temp\ipykernel_28984\804588024.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_df.groupby('Group').mean()
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business            44633.333333              75083.333333
# HASS                37186.363636              62968.181818
# STEM                53862.500000              90812.500000
#
#           Mid-Career 10th Percentile Salary  \
# Group
# Business                       43566.666667
# HASS                           34145.454545
# STEM                           56025.000000
#
#           Mid-Career 90th Percentile Salary           diff
# Group
# Business                      147525.000000  103958.333333
# HASS                          129363.636364   95218.181818
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format
clean_df.groupby('Group').mean()
# Out:
# C:\Users\basak\AppData\Local\Temp\ipykernel_28984\1335618228.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_df.groupby('Group').mean()
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business               44,633.33                 75,083.33
# HASS                   37,186.36                 62,968.18
# STEM                   53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  \
# Group
# Business                          43,566.67
# HASS                              34,145.45
# STEM                              56,025.00
#
#           Mid-Career 90th Percentile Salary       diff
# Group
# Business                         147,525.00 103,958.33
# HASS                             129,363.64  95,218.18
# ...

# %%
import requests
import bs4

from bs4 import BeautifulSoup
import requests
import pandas as df
import json
 
url = 'https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors'
 
url_list = []
url_list.append(url)
for numbers in range(2, 35):
    url_list.append(url + f'/page/{numbers}')
 
rank = []
field = []
early_pay = []
mid_career = []
high_mean = []
 
for item in url_list:
    response = requests.get(item)
    new_stat = response.text
 
    soup = BeautifulSoup(new_stat, 'html.parser')
    pay = soup.find_all(name="span", class_="data-table__value")
 
 
    i = 0
    for item in pay:
        if i == 0:
            rank.append(item.text)
            i += 1
        elif i == 1:
            field.append(item.text)
            i += 1
        elif i == 2:
            i += 1
        elif i == 3:
            early_pay.append(item.text)
            i += 1
        elif i == 4:
            mid_career.append(item.text)
            i += 1
        else:
            high_mean.append(item.text)
            i = 0
 
 
# print(soup.prettify())
 
page = df.DataFrame(
    {
        "Rank": rank,
        "Field": field,
        "Early Career Pay": early_pay,
        "Mid-Career Pay": mid_career,
        "% High Meaning" : high_mean,
    }
)
 
page.to_csv("new_data.csv", index=False)
